# %% [markdown]
# <a href="https://colab.research.google.com/github/450fausto/DatosPyE/blob/main/Ojiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/450fausto/DatosPyE/main/Ligas_Europa/LaLiga_2021_2022.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Date  HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0           0  13/08/2021  Valencia       Getafe     1     0   H     1     0
# 1           1  14/08/2021     Cadiz      Levante     1     1   D     0     1
# 2           2  14/08/2021  Mallorca        Betis     1     1   D     1     0
# 3           3  14/08/2021    Alaves  Real Madrid     1     4   A     0     0
# 4           4  14/08/2021   Osasuna      Espanol     0     0   D     0     0
#
#   HTR  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0   H  ...    2    4  24  15   1   9   6   3   1   1
# 1   A  ...    2    3  10  16   2   4   1   5   0   0
# 2   H  ...    2    1  12  18   4   3   1   3   0   0
# 3   D  ...    4    7  14  10   0   4   1   2   0   0
# 4   D  ...    1    3  18  12   4   6   3   3   0   0
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  380 non-null    int64
#  1   Date        380 non-null    object
#  2   HomeTeam    380 non-null    object
#  3   AwayTeam    380 non-null    object
#  4   FTHG        380 non-null    int64
#  5   FTAG        380 non-null    int64
#  6   FTR         380 non-null    object
#  7   HTHG        380 non-null    int64
#  8   HTAG        380 non-null    int64
#  9   HTR         380 non-null    object
#  10  HS          380 non-null    int64
#  11  AS          380 non-null    int64
#  12  HST         380 non-null    int64
#  13  AST         380 non-null    int64
#  14  HF          380 non-null    int64
#  15  AF          380 non-null    int64
#  16  HC          380 non-null    int64
#  17  AC          380 non-null    int64
#  18  HY          380 non-null    int64
#  19  AY          380 non-null    int64
#  20  HR          380 non-null    int64
#  21  AR          380 non-null    int64
# dtypes: int64(17), object(5)
# memory usage: 65.4+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0        FTHG        FTAG        HTHG        HTAG          HS  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean   189.500000    1.421053    1.081579    0.626316    0.465789   13.028947
# std    109.840794    1.250469    1.121240    0.787328    0.727440    4.739850
# min      0.000000    0.000000    0.000000    0.000000    0.000000    2.000000
# 25%     94.750000    0.750000    0.000000    0.000000    0.000000   10.000000
# 50%    189.500000    1.000000    1.000000    0.000000    0.000000   12.000000
# 75%    284.250000    2.000000    2.000000    1.000000    1.000000   16.000000
# max    379.000000    6.000000    6.000000    4.000000    4.000000   36.000000
#
#                AS         HST         AST          HF          AF          HC  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean    10.521053    4.392105    3.563158   13.615789   12.821053    5.215789
# std      4.263990    2.440088    2.157080    3.711177    4.022310    2.790062
# min      1.000000    0.000000    0.000000    5.000000    1.000000    0.000000
# 25%      7.000000    3.000000    2.000000   11.000000   10.000000    3.000000
# 50%     10.000000    4.000000    3.000000   13.000000   13.000000    5.000000
# 75%     13.000000    6.000000    5.000000   16.000000   15.000000    7.000000
# max     24.000000   16.000000   11.000000   25.000000   25.000000   16.000000
#
#                AC          HY          AY          HR          AR
# count  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     4.207895    2.497368    2.644737    0.128947    0.102632
# std      2.482964    1.508986    1.597359    0.343356    0.328896
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000    1.000000    2.000000    0.000000    0.000000
# 50%      4.000000    2.000000    3.000000    0.000000    0.000000
# 75%      6.000000    3.000000    4.000000    0.000000    0.000000
# max     12.000000    8.000000    7.000000    2.000000    2.000000

# %%
df['goles']=df['FTHG']+df['FTAG'] # Crear una nueva columna

# %%
# Ojiva
columna_interes = 'goles'

vals=df[columna_interes].value_counts().sort_index()
ax = vals.cumsum().plot(
                        kind="line", # Tipo de gráfico: line chart 
                        style='o-', # Estilo: 'o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd' con '-', '--', '-.', ':'
                        legend="",  # Leyenda no necesaria para la ojiva
                        color = 'black', # Colores para la línea
                        figsize=(10,6), # Tamaño (m,n) m: ancho, n: alto
                        fontsize=20, #Tamaño de letra
                        ylim=(0,400), # Límite superior e inferior para el eje 'y'
                        yticks=[0,200,300,350,375], # Líneas horizontales
                        rot=45 # Inclinación de las etiquetas en grados
                        )

ax.set_title('Ojiva', # Título del gráfico
             fontsize=20, # Tamaño de letra del título
             loc='center') # Localización del título: 'left' 'center' 'right'
ax.set_xlabel('Categorias', fontsize=12) # Nombre del eje 'x' y tamaño de letra
ax.set_ylabel('Frecuencia', fontsize=12) # Nombre del eje 'x' y tamaño de letra

ax.grid(axis='y',          # Maya del eje 'y'
        color='gray',      # Color de la maya en eje 'y'
        linestyle='--',    # Estilo de línea
        linewidth=0.5)     # Ancho de línea

ax.grid(axis='x', linewidth=0.5)

# %%
# Ojiva
columna_interes = 'goles'

vals=df[columna_interes].value_counts().sort_index()
ax = (100*vals.cumsum()/max(vals.cumsum())).plot(
                        kind="line", # Tipo de gráfico: bar chart 
                        style='o-', # Estilo: 'o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd' con '-', '--', '-.', ':'
                        legend="",  # Leyenda no necesaria para gráfico de barras
                        color = 'black', # Colores para las barras
                        figsize=(10,6), # Tamaño (m,n) m: ancho, n: alto
                        fontsize=20, #Tamaño de letra
                        ylim=(0,102), # Límite superior e inferior para el eje 'y'
                        yticks=[0,25,65,85,95,100], # Líneas horizontales
                        rot=45 # Inclinación de las etiquetas en grados
                        )

ax.set_title('Ojiva', # Título del gráfico
             fontsize=20, # Tamaño de letra del título
             loc='right') # Localización del título: 'left' 'center' 'right'
ax.set_xlabel('Categorias', fontsize=12) # Nombre del eje 'x' y tamaño de letra
ax.set_ylabel('Frecuencia %', fontsize=12) # Nombre del eje 'x' y tamaño de letra

ax.grid(axis='y',          # Maya del eje 'y'
        color='gray',      # Color de la maya en eje 'y'
        linestyle='--',    # Estilo de línea
        linewidth=0.5)     # Ancho de línea

ax.grid(axis='x', linewidth=0.5)
